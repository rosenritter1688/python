# %%
a = 1
b = "test"
print(type(a))
# Out:
# <class 'int'>

# %%
x = 3
n = x ^ 3
print(str(n))
# Out:
# 0

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
print(thislist[-1])
# Out:
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:-2])
# Out:
# ['cherry', 'orange', 'kiwi']
